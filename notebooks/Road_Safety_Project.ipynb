# %% [markdown]
# <a href="https://colab.research.google.com/github/borisyotsov/Road-Safety-in-Bulgaria-Impact-of-Traffic-and-Infrastructure-on-Accident-Rates/blob/main/Road_Safety_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Road Safety in Bulgaria
#
# ## Objective
# The goal of this project is to analyze how traffic intensity and road infrastructure affect road accidents in Bulgaria.

# %% [markdown]
# ## Problem Definition
#
# Road accidents are a major issue...
# We aim to investigate:
# - Does increased traffic lead to more accidents?
# - Does improved infrastructure reduce accident severity?
